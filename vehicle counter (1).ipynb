# %%
import cv2
import numpy as np

# %%
cap=cv2.VideoCapture("video.mp4")
count_line_pos=550
min_width_rect=80
min_higth_rect=80
algo=cv2.createBackgroundSubtractorMOG2()

def center_handle(x,y,w,h):
    x1=int(w/2)
    y1=int(h/2)
    cx=x+x1
    cy=y+y1
    return cx,cy
detect=[]
offset=6
counter=0

# %%
while True:
    ret,frame1=cap.read()
    grey=cv2.cvtColor(frame1,cv2.COLOR_BGR2GRAY)
    blur=cv2.GaussianBlur(grey,(3,3),5)
    img_sub=algo.apply(blur)
    
    dilat=cv2.dilate(img_sub,np.ones((5,5)))
    kernel=cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(5,5))
    dilatada=cv2.morphologyEx(dilat,cv2.MORPH_CLOSE,kernel)
    dilatada=cv2.morphologyEx(dilatada,cv2.MORPH_CLOSE,kernel)
    counterShape,h=cv2.findContours(dilatada,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    cv2.line(frame1,(25,count_line_pos),(1200,count_line_pos),(255,127,0),3)
    for(i,c) in enumerate(counterShape):
        (x,y,w,h)=cv2.boundingRect(c)
        validate_counter=(w>=min_width_rect)and(h>=min_higth_rect)
        if not validate_counter:
            continue
        cv2.rectangle(frame1,(x,y),(x+w,y+h),(0,255,0),2)
        cv2.putText(frame1,'vehicle'+str(counter),(x,y-20),cv2.FONT_HERSHEY_SIMPLEX,1,(255,244,0),2)
        center=center_handle(x,y,w,h)
        detect.append(center)
        cv2.circle(frame1,center,4,(0,0,255),-1)
        for(x,y) in detect:
            if y<(count_line_pos+offset)and y>(count_line_pos-offset):
                counter+=1
                cv2.line(frame1,(25,count_line_pos),(1200,count_line_pos),(0,127,255),3)
                detect.remove((x,y))
                print("vehicle counter:"+str(counter))
    cv2.putText(frame1,"vehicle counter: "+str(counter),(450,70),cv2.FONT_HERSHEY_SIMPLEX,2,(0,0,255),5)
    cv2.imshow("video",frame1)
    #cv2.imshow("detector",dilatada)
    
    if cv2.waitKey(1)==13:
        break
cv2.destroyAllWindows()
cap.release()
# Out:
# vehicle counter:1
# vehicle counter:2
# vehicle counter:3
# vehicle counter:4
# vehicle counter:5
# vehicle counter:6
# vehicle counter:7
# vehicle counter:8
# vehicle counter:9
# vehicle counter:10
# vehicle counter:11
# vehicle counter:12
# vehicle counter:13
# vehicle counter:14
# vehicle counter:15
# vehicle counter:16
# vehicle counter:17
# vehicle counter:18
# vehicle counter:19
# vehicle counter:20
# vehicle counter:21
# vehicle counter:22
# vehicle counter:23
# vehicle counter:24
# vehicle counter:25
# vehicle counter:26
# vehicle counter:27
# vehicle counter:28
# vehicle counter:29
# vehicle counter:30
# vehicle counter:31
# vehicle counter:32
# vehicle counter:33
# vehicle counter:34
# vehicle counter:35
# vehicle counter:36
# vehicle counter:37
# vehicle counter:38
# vehicle counter:39
# vehicle counter:40
# vehicle counter:41
# vehicle counter:42
# vehicle counter:43
# vehicle counter:44
# vehicle counter:45
# vehicle counter:46
# vehicle counter:47
# vehicle counter:48
# vehicle counter:49
# vehicle counter:50
# vehicle counter:51
# vehicle counter:52
# vehicle counter:53
# vehicle counter:54
# vehicle counter:55
# vehicle counter:56
# vehicle counter:57
# vehicle counter:58
# vehicle counter:59
# vehicle counter:60
# vehicle counter:61
# vehicle counter:62
# vehicle counter:63
# vehicle counter:64
# vehicle counter:65
# vehicle counter:66
# vehicle counter:67
# vehicle counter:68
# vehicle counter:69
# vehicle counter:70
# vehicle counter:71
# vehicle counter:72
# vehicle counter:73
# vehicle counter:74
# vehicle counter:75
# vehicle counter:76
# vehicle counter:77
# vehicle counter:78
# vehicle counter:79
# vehicle counter:80
# vehicle counter:81
# vehicle counter:82
# vehicle counter:83
# vehicle counter:84
# vehicle counter:85
# vehicle counter:86
# vehicle counter:87
# vehicle counter:88
# vehicle counter:89
# vehicle counter:90
# vehicle counter:91
# vehicle counter:92
# vehicle counter:93
# vehicle counter:94
# vehicle counter:95
# vehicle counter:96
# vehicle counter:97
# vehicle counter:98
# vehicle counter:99
# vehicle counter:100
# vehicle counter:101
# vehicle counter:102
# vehicle counter:103
# vehicle counter:104
# vehicle counter:105
# vehicle counter:106
# vehicle counter:107
# vehicle counter:108
# vehicle counter:109
# vehicle counter:110
# vehicle counter:111
# vehicle counter:112
# vehicle counter:113
# vehicle counter:114
# vehicle counter:115
# vehicle counter:116
# vehicle counter:117
# vehicle counter:118
# vehicle counter:119
# vehicle counter:120
# vehicle counter:121
# vehicle counter:122
# vehicle counter:123
# vehicle counter:124
# vehicle counter:125
# vehicle counter:126
# vehicle counter:127
# vehicle counter:128
# vehicle counter:129
# vehicle counter:130
# vehicle counter:131
# vehicle counter:132
# vehicle counter:133
# vehicle counter:134
# vehicle counter:135
# vehicle counter:136
# vehicle counter:137
# vehicle counter:138
# vehicle counter:139
# vehicle counter:140
# vehicle counter:141
# vehicle counter:142
# vehicle counter:143
# vehicle counter:144
# vehicle counter:145
# vehicle counter:146
# vehicle counter:147
# vehicle counter:148
# vehicle counter:149
# vehicle counter:150
# vehicle counter:151
# vehicle counter:152
# vehicle counter:153
# vehicle counter:154
# vehicle counter:155
# vehicle counter:156
# vehicle counter:157
# vehicle counter:158
# vehicle counter:159
# vehicle counter:160
# vehicle counter:161
# vehicle counter:162
# vehicle counter:163
# vehicle counter:164
# vehicle counter:165
# vehicle counter:166
# vehicle counter:167
# vehicle counter:168
# vehicle counter:169
# vehicle counter:170
# vehicle counter:171
# vehicle counter:172
# vehicle counter:173
# vehicle counter:174
# vehicle counter:175
# vehicle counter:176
# vehicle counter:177
# vehicle counter:178
# vehicle counter:179
# vehicle counter:180
# vehicle counter:181
# vehicle counter:182
# vehicle counter:183
# vehicle counter:184
# vehicle counter:185
# vehicle counter:186
# vehicle counter:187
# vehicle counter:188
# vehicle counter:189
# vehicle counter:190
# vehicle counter:191
# vehicle counter:192
# vehicle counter:193
# vehicle counter:194
# vehicle counter:195
# vehicle counter:196
# vehicle counter:197
# vehicle counter:198
# vehicle counter:199
# vehicle counter:200
# vehicle counter:201
# vehicle counter:202
# vehicle counter:203
# vehicle counter:204
# vehicle counter:205
# vehicle counter:206
# vehicle counter:207
# vehicle counter:208
# vehicle counter:209
# vehicle counter:210
# vehicle counter:211
# vehicle counter:212
# vehicle counter:213
# vehicle counter:214
# vehicle counter:215
# vehicle counter:216
# vehicle counter:217
# vehicle counter:218
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       1 while True:
#       2     ret,frame1=cap.read()
# ----> 3     grey=cv2.cvtColor(frame1,cv2.COLOR_BGR2GRAY)
#       4     blur=cv2.GaussianBlur(grey,(3,3),5)
#       5     img_sub=algo.apply(blur)
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
